# %% [markdown]
# # To make data-driven decision at scale
# ** The art and science of leveraging data to get actionable insights and make better decisions is know as making data-driven decision.**

# %% [markdown]
# ![image.png](attachment:image.png)
